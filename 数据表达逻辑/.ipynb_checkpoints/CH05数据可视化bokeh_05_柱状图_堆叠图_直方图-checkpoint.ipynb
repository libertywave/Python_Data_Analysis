# %%
'''
【课程5.6】  柱状图/堆叠图/直方图

① 单系列柱状图
② 多系列柱状图
③ 堆叠图
④ 直方图

'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

import warnings
warnings.filterwarnings('ignore') 
# 不发出警告

from bokeh.io import output_notebook
output_notebook()
# 导入notebook绘图模块

from bokeh.plotting import figure,show
from bokeh.models import ColumnDataSource
# 导入图表绘制、图标展示模块
# 导入ColumnDataSource模块
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b0fb0587-d10b-4200-87e4-a956cc7e43c3">Loading BokehJS ...</span>
#     </div>

# %%
# 1、单系列柱状图
# vbar

p = figure(plot_width=400, plot_height=400)
p.vbar(x=[1, 2, 3], width=0.5, bottom=0,top=[1.2, 2.5, 3.7],  # x：横轴坐标，width：宽度，bottom：底高度，top：顶高度
       #color = ['red','blue','green'], alpha = 0.8   # 整体颜色设置，也可单独设置 → color="firebrick"
       line_width = 1,line_alpha = 0.8,line_color = 'black', line_dash = [5,2],    # 单独设置线参数
       fill_color = 'red',fill_alpha = 0.6    # 单独设置填充颜色参数
      )
# 绘制竖向柱状图

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="93650724-a9cc-4afa-9272-6e14b4cfef05"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("93650724-a9cc-4afa-9272-6e14b4cfef05");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("93650724-a9cc-4afa-9272-6e14b4cfef05");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '93650724-a9cc-4afa-9272-6e14b4cfef05' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fd447acb-26f2-42de-8468-27b8f0982566":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"red"},"line_alpha":{"value":0.8},"line_dash":[5,2],"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"f438faf1-a25b-47ea-a4b5-d4e1d0f7db39","type":"VBar"},{"attributes":{},"id":"c3e0934f-87d8-4caa-921c-409b97179049","type":"SaveTool"},{"attributes":{},"id":"4bc0b37e-e7a8-4a38-8491-aa0d3f24467b","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["top","x"],"data":{"top":[1.2,2.5,3.7],"x":[1,2,3]}},"id":"f0a3ad9f-0a96-4bf9-8bd6-57ad1d08bef3","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"b0b48b95-43db-43fc-b706-ac975dc400b7","type":"BoxAnnotation"}},"id":"21dd409b-df99-40dd-bf9a-3406772f597c","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"d188b796-8ff0-44b0-859c-fe609e15c0a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"15c4ec50-00de-46ce-ae2a-a2f88c991c22","type":"BasicTicker"}},"id":"0cccb763-5f65-4842-b4d5-4b248fd1bf88","type":"Grid"},{"attributes":{"source":{"id":"f0a3ad9f-0a96-4bf9-8bd6-57ad1d08bef3","type":"ColumnDataSource"}},"id":"c98ffd8f-fefc-489e-b8d2-2de6f4e25e54","type":"CDSView"},{"attributes":{},"id":"15c4ec50-00de-46ce-ae2a-a2f88c991c22","type":"BasicTicker"},{"attributes":{},"id":"3a495aff-0acf-49ed-b38e-c58eba07467c","type":"LinearScale"},{"attributes":{"formatter":{"id":"4bc0b37e-e7a8-4a38-8491-aa0d3f24467b","type":"BasicTickFormatter"},"plot":{"id":"d188b796-8ff0-44b0-859c-fe609e15c0a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc5aa3cf-d81d-45a6-b6c3-bfbb97be4f20","type":"BasicTicker"}},"id":"4e9ca2e6-f92e-41bf-b40b-6f9862e20922","type":"LinearAxis"},{"attributes":{"plot":{"id":"d188b796-8ff0-44b0-859c-fe609e15c0a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc5aa3cf-d81d-45a6-b6c3-bfbb97be4f20","type":"BasicTicker"}},"id":"b446da51-612c-4bff-8743-05cfdf4bfd9f","type":"Grid"},{"attributes":{"data_source":{"id":"f0a3ad9f-0a96-4bf9-8bd6-57ad1d08bef3","type":"ColumnDataSource"},"glyph":{"id":"f438faf1-a25b-47ea-a4b5-d4e1d0f7db39","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"21c82baf-3329-4b56-916f-a47a82a7a65c","type":"VBar"},"selection_glyph":null,"view":{"id":"c98ffd8f-fefc-489e-b8d2-2de6f4e25e54","type":"CDSView"}},"id":"95f63cbc-e2c6-410f-a053-7a70c2ecd8a4","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[5,2],"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"21c82baf-3329-4b56-916f-a47a82a7a65c","type":"VBar"},{"attributes":{"plot":null,"text":""},"id":"83f94d15-296c-4a5f-91b0-66487a21f546","type":"Title"},{"attributes":{},"id":"2f6b4716-7e2d-4763-95d3-5ebd6b263758","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"8e6846ab-a94d-42f4-b2f5-17a2cc8326f8","type":"DataRange1d"},{"attributes":{"below":[{"id":"4e9ca2e6-f92e-41bf-b40b-6f9862e20922","type":"LinearAxis"}],"left":[{"id":"c46b29d8-52d8-4a26-86b8-ad1814e3fd71","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"4e9ca2e6-f92e-41bf-b40b-6f9862e20922","type":"LinearAxis"},{"id":"b446da51-612c-4bff-8743-05cfdf4bfd9f","type":"Grid"},{"id":"c46b29d8-52d8-4a26-86b8-ad1814e3fd71","type":"LinearAxis"},{"id":"0cccb763-5f65-4842-b4d5-4b248fd1bf88","type":"Grid"},{"id":"b0b48b95-43db-43fc-b706-ac975dc400b7","type":"BoxAnnotation"},{"id":"95f63cbc-e2c6-410f-a053-7a70c2ecd8a4","type":"GlyphRenderer"}],"title":{"id":"83f94d15-296c-4a5f-91b0-66487a21f546","type":"Title"},"toolbar":{"id":"401a4904-cd44-4ea3-8a13-1f403ecf7fd7","type":"Toolbar"},"x_range":{"id":"8e6846ab-a94d-42f4-b2f5-17a2cc8326f8","type":"DataRange1d"},"x_scale":{"id":"169f60ae-6a19-4cc0-a457-b116dbc0ac15","type":"LinearScale"},"y_range":{"id":"6060905d-b90b-40be-b103-925ba0016fae","type":"DataRange1d"},"y_scale":{"id":"3a495aff-0acf-49ed-b38e-c ...

# %%
# 1、单系列柱状图
# hbar

p = figure(plot_width=400, plot_height=400)
p.hbar(y=[1, 2, 3], height=0.5, left=0,right=[1.2, 2.5, 3.7],  # y：纵轴坐标，height：厚度，left：左边最小值，right：右边最大值
       color = ['red','blue','green'])
# 绘制竖向柱状图

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51c68ea1-f979-4ec3-9da4-d95977ce8024"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("51c68ea1-f979-4ec3-9da4-d95977ce8024");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51c68ea1-f979-4ec3-9da4-d95977ce8024");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51c68ea1-f979-4ec3-9da4-d95977ce8024' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"25eb2d12-a593-405a-a2b9-fd310bcabd37":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"1ec4dbd4-c826-4f97-b77c-f2ac41543b4a","type":"Title"},{"attributes":{"formatter":{"id":"03c4e534-65de-4206-9fc3-9201049cff1b","type":"BasicTickFormatter"},"plot":{"id":"7f6689c5-3161-4541-a960-6d63ef7d9dad","subtype":"Figure","type":"Plot"},"ticker":{"id":"9771a7ee-4925-468d-b7fe-5d71733d1da7","type":"BasicTicker"}},"id":"1e04377d-a601-453a-8f49-d49b08cf2f53","type":"LinearAxis"},{"attributes":{},"id":"092de59d-6370-4422-a13c-091243c257b3","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y
-4925-468d-b7fe-5d71733d1da7","type":"BasicTicker"}},"id":"7ed6dd23-c1bd-46a9-91d8-9d0471643744","type":"Grid"},{"attributes":{"formatter":{"id":"092de59d-6370-4422-a13c-091243c257b3","type":"BasicTickFormatter"},"plot":{"id":"7f6689c5-3161-4541-a960-6d63ef7d9dad","subtype":"Figure","type":"Plot"},"ticker":{"id":"ffa3eb25-b639-460a-90c8-50065763fded","type":"BasicTicker"}},"id":"e29ac546-8af0-4c91-90ba-dc89061bfab2","type":"LinearAxis"},{"attributes":{},"id":"2429de09-f095-4fc6-84f7-909b80cea182","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5} ...

# %%
# 1、单系列柱状图 - 分类设置标签
# ColumnDataSource

from bokeh.palettes import Spectral6
from bokeh.transform import factor_cmap
# 导入相关模块

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]
source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))
colors = [ "salmon", "olive", "darkred", "goldenrod", "skyblue", "orange"]
# 创建一个包含标签的data，对象类型为ColumnDataSource

p = figure(x_range=fruits, y_range=(0,9), plot_height=350, title="Fruit Counts",tools="")

p.vbar(x='fruits', top='counts', source=source,    # 加载数据另一个方式
       width=0.9, alpha = 0.8,
       color = factor_cmap('fruits', palette=Spectral6, factors=fruits),    # 设置颜色
       legend="fruits")
# 绘制柱状图，横轴直接显示标签
# factor_cmap(field_name, palette, factors, start=0, end=None, nan_color='gray')：颜色转换模块，生成一个颜色转换对象
# field_name：分类名称
# palette：调色盘
# factors：用于在调色盘中分颜色的参数
# 参考文档：http://bokeh.pydata.org/en/latest/docs/reference/transform.html

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
# 其他参数设置

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="72918f1a-6905-43d6-a993-2eb2f19509e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("72918f1a-6905-43d6-a993-2eb2f19509e7");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("72918f1a-6905-43d6-a993-2eb2f19509e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '72918f1a-6905-43d6-a993-2eb2f19509e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f161b127-c661-4cae-aad7-c5a4f309eb09":{"roots":{"references":[{"attributes":{"below":[{"id":"1a35e7cc-239a-414c-bbbd-fa1325cbdd89","type":"CategoricalAxis"}],"left":[{"id":"0c25420e-6918-48e5-9190-4b64405c34e4","type":"LinearAxis"}],"plot_height":350,"renderers":[{"id":"1a35e7cc-239a-414c-bbbd-fa1325cbdd89","type":"CategoricalAxis"},{"id":"93153f30-f0db-4641-8e3d-c658512073d5","type":"Grid"},{"id":"0c25420e-6918-48e5-9190-4b64405c34e4","type":"LinearAxis"},{"id":"e7feff89-ea1a-4dbc-b49f-09feb870613c","type":"Grid"},{"id":"b5a8a2fc-09c5-455a-800c-34c5efecced8","type":"Legend"},{"id":"38b756e5-3355-4a5a-846b-73c47bf50ac6","type":"GlyphRenderer"}],"title":{"id":"a2a76035-174a-44e2-93a8-b183106bec84","type":"Title"},"toolbar":{"id":"114039f2-eadb-4a0c-969c-bab8a8b448df","type":"Toolbar"},"x_range":{"id":"790d4c28-716a-41f9-a2e4-9c0c4e4f99c7","type":"FactorRange"},"x_scale":{"id":"8bdd7b5f-3e0e-4149-8d80-39c47e38eba1","type":"CategoricalScale"},"y_range":{"id":"8fb47f89-deec-4dd4-a59d-464aa1f212b5","type":"Range1d"},"y_scale":{"id":"a3a2c279-a0c0-44bb-bd99-41ba51ea691e","type":"LinearScale"}},"id":"e6b83d42-e8cf-417a-ac2b-a884e9d5769f","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto"},"id":"114039f2-eadb-4a0c-969c-bab8a8b448df","type":"Toolbar"},{"attributes":{"formatter":{"id":"63d722a0-1f6d-4c9e-8ed4-eb71840a5b4c","type":"BasicTickFormatter"},"plot":{"id":"e6b83d42-e8cf-417a-ac2b-a884e9d5769f","subtype":"Figure","type":"Plot"},"ticker":{"id":"385a33c4-e4d5-4656-9db5-9c6499e3998d","type":"BasicTicker"}},"id":"0c25420e-6918-48e5-9190-4b64405c34e4","type":"LinearAxis"},{"attributes":{"data_source":{"id":"1f95439b-9071-407f-97a3-2bc0ce39b066","type":"ColumnDataSource"},"glyph":{"id":"564442ac-c39b-469a-be3b-8736087fd2b6","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d9946620-a929-46a2-95d7-0586b1597f85","type":"VBar"},"selection_glyph":null,"view":{"id":"215f40e4-dea8-4789-8ec1-59a15a19b72b","type":"CDSView"}},"id":"38b756e5-3355-4a5a-846b-73c47bf50ac6","type":"GlyphRenderer"},{"attributes":{},"id":"c50cb68b-1f3f-4398-b4fd-d02c9fb114ae","type":"CategoricalTicker"},{"attributes":{},"id":"385a33c4-e4d5-4656-9db5-9c6499e3998d","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["counts","fruits"],"data":{"counts":[5,3,4,2,4,6],"fruits":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"]}},"id":"1f95439b-9071-407f-97a3-2bc0ce39b066","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":9},"id":"8fb47f89-deec-4dd4-a59d-464aa1f212b5","type":"Range1d"},{"attributes":{"source":{"id":"1f95439b-9071-407f-97a3-2bc0ce39b066","type":"ColumnDataSource"}},"id":"215f40e4-dea8-4789-8ec1-59a15a19b72b","type":"CDSView"},{"attributes":{},"id":"a3a2c279-a0c0-44bb-bd99-41ba51ea691e","type":"LinearScale"},{"attributes":{"plot":null,"text":"Fruit Counts"},"id":"a2a76035-174a-44e2-93a8-b183106bec84","type":"Title"},{"attributes":{},"id":"63d722a0-1f6d-4c9e-8ed4-eb71840a5b4c","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"field":"fruits","transform":{"id":"e380d125-2caf-4d41-b991-59b2e9ec0636","type":"CategoricalColorMapper"}},"line_alpha":{"value":0.8},"line_color":{"field":"fruits","transform":{"id":"e380d125-2caf-4d41-b991-59b2e9ec0636","type":"CategoricalColorMapper"}},"top":{"field":"counts"},"width":{"value":0.9},"x":{"field":"fruits"}},"id":"564442ac-c39b-469a-be3b-8736087fd2b6","type":"VBar"},{"attributes":{"formatter":{"id":"57f5a424-7d74-4e95-a85c-4739792c6140","type":"CategoricalTickFormatter"},"plot":{"id":"e6b83d42-e8cf-417a-ac2b-a884e9d5769f","subtype":"Figure","type":"Plot"},"ticker":{"id":"c50cb68b-1f3f-4398-b4fd-d02c9fb114ae","type":"CategoricalTicker"}},"id":"1a35e7cc-239a-414c-bbbd-fa1325cbdd89","type":"CategoricalAxis"},{"attributes":{"factors":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"],"pale ...

# %%
# 2、多系列柱状图
# vbar

from bokeh.transform import dodge
from bokeh.core.properties import value
# 导入dodge、value模块

df = pd.DataFrame({'2015':[2, 1, 4, 3, 2, 4],'2016':[5, 3, 3, 2, 4, 6], '2017':[3, 2, 4, 4, 5, 3]},
                 index = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'])
# 创建数据

fruits = df.index.tolist()   # 横坐标
years = df.columns.tolist()    # 系列名
data = {'index':fruits}
for year in years:
    data[year] = df[year].tolist()
print(data)
# 生成数据，数据格式为dict

source = ColumnDataSource(data=data)
# 将数据转化为ColumnDataSource对象

p = figure(x_range=fruits, y_range=(0, 10), plot_height=350, title="Fruit Counts by Year",tools="")

p.vbar(x=dodge('index', -0.25, range=p.x_range), top='2015', width=0.2, source=source,color="#c9d9d3", legend=value("2015"))
p.vbar(x=dodge('index',  0.0,  range=p.x_range), top='2016', width=0.2, source=source,color="#718dbf", legend=value("2016"))
p.vbar(x=dodge('index',  0.25, range=p.x_range), top='2017', width=0.2, source=source,color="#e84d60", legend=value("2017"))
# 绘制多系列柱状图
# dodge(field_name, value, range=None) → 转换成一个可分组的对象，value为元素的位置（配合width设置）
# value(val, transform=None) → 按照年份分为dict

p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"
# 其他参数设置

show(p)
# Out:
# {'2017': [3, 2, 4, 4, 5, 3], '2016': [5, 3, 3, 2, 4, 6], 'index': ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'], '2015': [2, 1, 4, 3, 2, 4]}
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a1881bf8-2972-4801-9bf0-72010a03580d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("a1881bf8-2972-4801-9bf0-72010a03580d");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a1881bf8-2972-4801-9bf0-72010a03580d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a1881bf8-2972-4801-9bf0-72010a03580d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eda30502-7fd0-4ce3-9fe8-d7a98363c863":{"roots":{"references":[{"attributes":{"formatter":{"id":"9b5f10a2-c8f7-467a-9a60-9bbfab6a2d1b","type":"CategoricalTickFormatter"},"plot":{"id":"0adcfccb-d95a-4741-a3bb-6fd1da647234","subtype":"Figure","type":"Plot"},"ticker":{"id":"96526262-080c-483f-bf9c-faf6f79e43ba","type":"CategoricalTicker"}},"id":"94c43278-47c4-45ab-9bdf-6762745446bf","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"2015"},"width":{"value":0.2},"x":{"field":"index","transform":{"id":"9723173d-4fd1-4c3f-b9bd-879c1ce2eff4","type":"Dodge"}}},"id":"0e724069-ffe4-4684-8d8f-034b7da5ee00","type":"VBar"},{"attributes":{"data_source":{"id":"7734a52e-f9c1-44cd-8eed-fb99cb266277","type":"ColumnDataSource"},"glyph":{"id":"6cb173f7-7bd0-4c97-96c4-031a303b7f9b","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0e724069-ffe4-4684-8d8f-034b7da5ee00","type":"VBar"},"selection_glyph":null,"view":{"id":"64e064ad-fb83-436b-b02b-3c03e01d24b0","type":"CDSView"}},"id":"9535135a-3103-49e8-867d-cacc79eb285a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7734a52e-f9c1-44cd-8eed-fb99cb266277","type":"ColumnDataSource"},"glyph":{"id":"dcce739c-433f-4c2b-81bd-3abaa9c8aa87","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4384b10c-9fe0-4179-87a3-7bfa506e8496","type":"VBar"},"selection_glyph":null,"view":{"id":"fb9e9f54-ae1c-47a5-9f3e-89042dfadf03","type":"CDSView"}},"id":"aca5d95f-2b21-49e9-88d0-7d3ce51fd6a1","type":"GlyphRenderer"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"0adcfccb-d95a-4741-a3bb-6fd1da647234","subtype":"Figure","type":"Plot"},"ticker":{"id":"96526262-080c-483f-bf9c-faf6f79e43ba","type":"CategoricalTicker"}},"id":"dcab0c5c-5342-47b0-9067-fef4cdd5f428","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto"},"id":"1b3c69de-b055-4e66-b72d-ac66c7b0f729","type":"Toolbar"},{"attributes":{"range":{"id":"b34d4e77-7dd7-41d2-ad83-5928386c6e68","type":"FactorRange"}},"id":"c70910b8-2d94-4849-aa28-37d0e0d81fa4","type":"Dodge"},{"attributes":{"callback":null,"factors":["Apples","Pears","Nectarines","Plums","Grapes","Strawberries"]},"id":"b34d4e77-7dd7-41d2-ad83-5928386c6e68","type":"FactorRange"},{"attributes":{"label":{"value":"2015"},"renderers":[{"id":"9535135a-3103-49e8-867d-cacc79eb285a","type":"GlyphRenderer"}]},"id":"1cc0001d-e4fe-4745-bbd6-38469bc6baf3","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"2017"},"width":{"value":0.2},"x":{"field":"index","transform":{"id":"5be74715-0712-4155-a22e-42bfc1166abf","type":"Dodge"}}},"id":"68957cfe-1487-47cf-a565-440766b248f7","type":"VBar"},{"attributes":{},"id":"7d184a25-65c0-41e9-8ab2-f506053b7acf","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":10},"id":"599823a5-780f-438c-ae08-b1f905f810d2","type":"Range1d"},{"attributes":{"plot":null,"text":"Fruit Counts by Year"},"id":"cf369489-fc63-44a4-8d49-224e5439fc25","type":"Title"},{"attributes":{},"id":"e85b457d-caa7-4a04-acf8-314ca89036d6","type":"BasicTicker"},{"attributes":{"source":{"id":"7734a52e-f9c1-44cd-8eed-fb99cb266277","type":"ColumnDataSource"}},"id":"64e064ad-fb83-436b-b02b-3c03e01d24b0","type":"CDSView"},{"attributes":{"range":{"id":"b34d4e77-7dd7-41d2-ad83-5928386c6e68","type":"FactorRange"},"value":-0.25},"id":"9723173d-4fd1-4c3f-b9bd-879c1ce2eff4","type":"Dodge"},{"attributes":{"dimension":1,"plot":{"id":"0adcfccb-d95a-4741-a3bb-6fd1da647234","subtype":"Figure","type":"Plot"},"ticker":{"id":"e85b457d-caa7-4a04-acf8-314ca89036d6","type":"BasicTicker"}},"id":"b91f6a2b-ff92-429b-ae84-ca70f6568e97","type":"Grid"},{"attributes":{"fill_color":{"value":"#e84d60"},"line_color":{"value" ...

# %%
# 3、堆叠图

from bokeh.core.properties import value
# 导入value模块

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ["2015", "2016", "2017"]
colors = ["#c9d9d3", "#718dbf", "#e84d60"]
data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 4, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}
source = ColumnDataSource(data=data)
# 创建数据

p = figure(x_range=fruits, plot_height=350, title="Fruit Counts by Year",tools="")
renderers = p.vbar_stack(years,          # 设置堆叠值，这里source中包含了不同年份的值，years变量用于识别不同堆叠层
                         x='fruits',     # 设置x坐标
                         source=source,
                         width=0.9, color=colors,
                         legend=[value(x) for x in years], name=years)
# 绘制堆叠图
# 注意第一个参数需要放years

p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal
subtype":"Figure","type":"Plot"},"ticker":{"id":"5b0ce294-71ba-4293-84dd-c5fd06fa74aa","type":"BasicTicker"}},"id":"3cc9a90d-ca47-4881-9d97-477c693076f8","type":"LinearAxis"},{"attributes":{"fields":["2015","2016"]},"id":"cb8c5d36-81ea-44c1-b287-3da88193f2bd","type":"Stack"},{"attributes":{"bottom":{"expr":{"id":"170f2876-0762-4172-be8f-697f24a57829","type":"Stack"}},"fill_color":{"value":"#e84d60"},"line_color":{"value":"#e84d60"},"top":{"expr":{"id":"7911c385-ab24-493e-9aa0-45a403ee5dc2","type":"Stack"}},"width":{"value":0.9},"x":{"field":"fruits"}},"id":"faaff866-d38b-4bcf-8f3d-e05ffa751cca","type":"VBar"},{"attributes":{"fields":[]},"id":"ee55dd45-7bdd-424d-8a64-347d2b054679","type":"Stack"},{"attributes":{"label":{"value":"2017"},"renderers":[{"id":"9cc3845d-0f27-46dc-85e4-76cf0a5ec3ca","type":"GlyphRenderer"}]},"id":"9c3c60c5-1071-4091-9299-e9e740054695","type":"LegendItem"},{"attributes":{"data_source":{"id":"471396cd-44cb-4496-b309-b072c89b7edc","type":"ColumnDataSource"},"glyph":{"id":"ed739eab-8574-44d7-8474-ff1e8e79d244","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"name":"2015","nonselection_glyph":{"id":"55c7fd8f-d765-4ed2-a74f-804bdc4ab685","type":"VBar"},"selection_glyph":null,"view":{"id":"e6a84528-78bd-4095-9f6a-f31ae81a386c","type":"CDSView"}},"id":"05952476-fe8 ...

# %%
# 3、堆叠图

from bokeh.palettes import GnBu3, OrRd3
# 导入颜色模块

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ["2015", "2016", "2017"]
exports = {'fruits' : fruits,
           '2015'   : [2, 1, 4, 3, 2, 4],
           '2016'   : [5, 3, 4, 2, 4, 6],
           '2017'   : [3, 2, 4, 4, 5, 3]}
imports = {'fruits' : fruits,
           '2015'   : [-1, 0, -1, -3, -2, -1],
           '2016'   : [-2, -1, -3, -1, -2, -2],
           '2017'   : [-1, -2, -1, 0, -2, -2]}

p = figure(y_range=fruits, plot_height=350, x_range=(-16, 16), title="Fruit import/export, by year")

p.hbar_stack(years, y='fruits', height=0.9, color=GnBu3, source=ColumnDataSource(exports),
             legend=["%s exports" % x for x in years])      # 绘制出口数据堆叠图

p.hbar_stack(years, y='fruits', height=0.9, color=OrRd3, source=ColumnDataSource(imports),
             legend=["%s imports" % x for x in years])      # 绘制进口数据堆叠图，这里值为负值

p.y_range.range_padding = 0.2     # 调整边界间隔
p.ygrid.grid_line_color = None   
p.legend.location = "top_left"
p.axis.minor_tick_line_color = None
p.outline_line_color = None
# 设置其他参数

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="35eeb147-cb7a-4992-8a9d-18d680b41b3e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("35eeb147-cb7a-4992-8a9d-18d680b41b3e");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("35eeb147-cb7a-4992-8a9d-18d680b41b3e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '35eeb147-cb7a-4992-8a9d-18d680b41b3e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1eb833e3-1490-45d9-9d9c-8bccbdbbf9e8":{"roots":{"references":[{"attributes":{"formatter":{"id":"09ab3432-7b34-41cb-aee6-8eb437cb97a8","type":"CategoricalTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"d2d829c9-d9c0-498b-8d90-51759243acb9","subtype":"Figure","type":"Plot"},"ticker":{"id":
a516f-6c00-474d-897e-957a6d46d557","type":"Toolbar"},"x_range":{"id":"fb89afcc-31b8-4518-88c0-fc029b6478e9","type":"Range1d"},"x_scale":{"id":"d1737199-3032-4c7d-b322-9712a28bac9b","type":"LinearScale"},"y_range":{"id":"e2b920bd-8a2b-4820-9907-626d63213e05","type":"FactorRange"},"y_scale":{"id":"2e6dcd64-7f5f-4a43-b0bf-0134af16c4dd","type":"CategoricalScale"}},"id":"d2d829c9-d9c0-498b-8d90-51759243acb9","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d1737199-3032-4c7d-b322-9712a28bac9b","type":"LinearScale"},{"attributes":{"label":{"value":"2016 exports"},"renderers":[{"id":"07a1cfed-ad67-41bb-a67b-3880038517f8","type":"GlyphRenderer"}]},"id":"51f95a2d-e89d-42c9-a745-fc364c7d8e21","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value": ...

# %%
# 4、直方图
# np.histogram + figure.quad()
# 不需要构建ColumnDataSource对象

df = pd.DataFrame({'value': np.random.randn(1000)*100})
df.index.name = 'index'
print(df.head())
# 创建数据

hist, edges = np.histogram(df['value'],bins=20)
print(hist[:5])
print(edges)
# 将数据解析成直方图统计格式
# 高阶函数np.histogram(a, bins=10, range=None, weights=None, density=None) 
# a：数据
# bins：箱数
# range：最大最小值的范围，如果不设定则为(a.min(), a.max())
# weights：权重
# density：为True则返回“频率”，为False则返回“计数”
# 返回值1 - hist：每个箱子的统计值（top）
# 返回值2 - edges：每个箱子的位置坐标，这里n个bins将会有n+1个edges

p = figure(title="HIST", tools="save",background_fill_color="#E8DDCB")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],   # 分别代表每个柱子的四边值
        fill_color="#036564", line_color="#033649")
# figure.quad绘制直方图

show(p)
# Out:
#             value
# index
# 0       -9.268074
# 1      -51.203490
# 2     -104.595005
# 3      105.004174
# 4       69.298714
# [ 3  4 11 18 22]
# [-324.82025667 -289.10943001 -253.39860335 -217.68777669 -181.97695004
#  -146.26612338 -110.55529672  -74.84447006  -39.1336434    -3.42281674
#    32.28800991   67.99883657  103.70966323  139.42048989  175.13131655
#   210.8421432   246.55296986  282.26379652  317.97462318  353.68544984
#   389.3962765 ]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ded9875-4432-40da-bf3f-7c43bf0258af"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7ded9875-4432-40da-bf3f-7c43bf0258af");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ded9875-4432-40da-bf3f-7c43bf0258af");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ded9875-4432-40da-bf3f-7c43bf0258af' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2fc10483-f577-439b-af66-f080be165f48":{"roots":{"references":[{"attributes":{},"id":"1315dbbc-0453-4a1d-8644-810a471a920d","type":"BasicTicker"},{"attributes":{"data_source":{"id":"21cfada4-51b1-4a89-8368-f763808ef3a4","type":"ColumnDataSource"},"glyph":{"id":"26d961f0-9325-43a7-b249-a87a2a3b7db5","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e15c7f22-b517-428a-8a9d-b64e298e2173","type":"Quad"},"selection_glyph":null,"view":{"id":"8dff9400-5695-4820-a400-4343b16e6f9d","type":"CDSView"}},"id":"08c51687-d628-4782-b320-d3f261fbdff7","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"e15c7f22-b517-428a-8a9d-b64e298e2173","type":"Quad"},{"attributes":{"source":{"id":"21cfada4-51b1-4a89-8368-f763808ef3a4","type":"ColumnDataSource"}},"id":"8dff9400-5695-4820-a400-4343b16e6f9d","type":"CDSView"},{"attributes":{"plot":{"id":"5ff72958-e63e-4bc7-9a82-2c474a028200","subtype":"Figure","type":"Plot"},"ticker":{"id":"c0da5218-94a3-4293-9a30-b19797bda975","type":"BasicTicker"}},"id":"040d77a1-5b5c-43da-b860-309c0151dffe","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"5ff72958-e63e-4bc7-9a82-2c474a028200","subtype":"Figure","type":"Plot"},"ticker":{"id":"1315dbbc-0453-4a1d-8644-810a471a920d","type":"BasicTicker"}},"id":"984bd694-6641-49af-8f2c-6f3a1ed88095","type":"Grid"},{"attributes":{},"id":"41546c87-f099-44db-bfa2-f12fc5e0902e","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"HIST"},"id":"f64ad93a-1608-49f4-b3db-fc9f8c12a64c","type":"Title"},{"attributes":{"callback":null},"id":"bbe09a96-a34b-4a78-a86d-d2b002d66efc","type":"DataRange1d"},{"attributes":{},"id":"57be65b2-fcf1-4007-9175-bb805d7f7f3a","type":"SaveTool"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"26d961f0-9325-43a7-b249-a87a2a3b7db5","type":"Quad"},{"attributes":{"formatter":{"id":"41546c87-f099-44db-bfa2-f12fc5e0902e","type":"BasicTickFormatter"},"plot":{"id":"5ff72958-e63e-4bc7-9a82-2c474a028200","subtype":"Figure","type":"Plot"},"ticker":{"id":"1315dbbc-0453-4a1d-8644-810a471a920d","type":"BasicTicker"}},"id":"d23f4e18-bb7d-4a26-8de1-47b70f5456fd","type":"LinearAxis"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"69494422-6957-4e5b-b504-5c85e7beb2f4","type":"LinearAxis"}],"left":[{"id":"d23f4e18-bb7d-4a26-8de1-47b70f5456fd","type":"LinearAxis"}],"renderers":[{"id":"69494422-6957-4e5b-b504-5c85e7beb2f4","type":"LinearAxis"},{"id":"040d77a1-5b5c-43da-b860-309c0151dffe","type":"Grid"},{"id":"d23f4e18-bb7d-4a26-8de1-47b70f5456fd","type":"LinearAxis"},{"id":"984bd694-6641-49af-8f2c-6f3a1ed88095","type":"Grid"},{"id":"08c51687-d628-4782-b320-d3f261fbdff7","type":"GlyphRenderer"}],"title":{"id":"f64ad93a-1608-49f4-b3db-fc9f8c12a64c","type":"Title"},"toolbar":{"id":"4b659055-1c77-468b-91c9-5abd1b8e172f","type":"Toolbar"},"x_range":{"id":"0344b880-cbb4-4228-a59d-eeafaf79c6c9","type":"DataRange1d"},"x_scale":{"id":"bb198a42-8372-4373-8416-ecc4b77f35f6","type":"LinearScale"},"y_range":{"id":"bbe09a96-a34b-4a78-a86d-d2b002d66efc","type":"DataRange1d"},"y_scale":{"id":"4a4a80b3-aa0e-44aa-b9f5-7a4129761914","type":"LinearScale"}},"id":"5ff72958-e63e-4bc7-9a82-2c474a028200","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"0344b880-cbb4-4228-a59d-eeafaf79c6c9","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"57be65b2-fcf1-4007-9175-bb805d7f7f3a","type":"SaveTool"}]},"id":"4b659055-1c77-468b-91c9-5abd1b8e172f","type":"Toolbar"},{"attributes":{},"id":"bb198a42-8372-4373-8416-ecc4b77f35f6","type":"LinearScale"},{"attributes ...
